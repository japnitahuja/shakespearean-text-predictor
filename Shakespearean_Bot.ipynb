# %% [markdown]
# <a href="https://colab.research.google.com/github/japnitahuja/shakespearean-text-predictor/blob/main/Shakespearean_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shakespeare Bot: An NLP Text Prediction Neural Network

# %% [markdown]
# ## Step 1: Data Collection + Data Cleaning

# %%
dataurl = "https://gist.githubusercontent.com/japnitahuja/89bb89e206cad7062f1d77e1768331b0/raw/58feb12be800b1f639a70451bf6370f47f8a9a38/shakespearean_monologues.txt"

# %%
from urllib.request import urlopen
data = urlopen(dataurl).read().decode('utf-8').split("\n")
print("Number of monologues: {}".format(len(data)))

unique = set([w for s in data for w in s.split()])
print("Number of unique words: {}".format(len(unique)))
# Out:
# Number of monologues: 638
# Number of unique words: 3256

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# get rid of blank lines
data = [line for line in data if line != '']

# plot word cloud to see most ised words
wordcloud = WordCloud().generate(' '.join(data))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Considering the data is the script from the Romeo and Juliet play, it seems fitting that "love" is one of the most used words.

# %%
import spacy

# tokenization
nlp = spacy.load("en_core_web_sm", disable=["parser", "tagger", "ner", "textcat"])
data = [nlp(s) for s in data]

# adding <n> tag to specify a new monologue
data = [ ["<n>"] + [str(w) for w in s] + ["</n>"] for s in data]

#split into train and validate
train = data[:-5]
valid = data[-5:]

# flatten the lists into one long string and remove extra whitespace
train = [w for s in train for w in s if not w.isspace()]
valid = [w for s in valid for w in s if not w.isspace()]
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
print("Training dataset contains {} lexical types (unique words)".format(len(set(train))))
print("Training dataset contains {} lexical tokens (number of words)".format(len(train)))
# Out:
# Training dataset contains 3212 lexical types (unique words)
# Training dataset contains 22170 lexical tokens (number of words)

# %%
import re
def simplify_word(w):
    # remove extra punctuation
    w = w.replace("-", "").replace("~","")

    # replace numbers with # sign
    w = re.sub('\d', '#', w)

    # split words into root and stem
    if len(w) > 3 and w[-2:] in set(["ed", "er","ly"]):
        return [w[:-2], w[-2:]]
    elif len(w) > 4 and w[-3:] in set(["ing","'re"]):
        return [w[:-3], w[-3:]]
    return [w]

# %%
# loop through all the words and perform data cleaning
train_clean = []
for w in train:
    for piece in simplify_word(w):
        train_clean.append(piece)

valid_clean = []
for w in valid:
    for piece in simplify_word(w):
        valid_clean.append(piece)

# %%
from collections import Counter

counts_clean = Counter(train_clean)

# only keeping the tokens in validation set that are already in train
train_new = [w for w in train_clean]
valid_new = [w for w in valid_clean if w in counts_clean]

# %%
# create a mapping from words <-> numbers
vocab = set(train_new)
word_to_num = {}
num_to_word = {}
for num, word in enumerate(vocab):
  word_to_num[word] = num
  num_to_word[num] = word

# convert our dataset tokens into integers
import torch
train = torch.LongTensor(len(train_new))
for i in range(len(train_new)):
  train[i] = word_to_num[train_new[i]]

valid = torch.LongTensor(len(valid_new))
for i in range(len(valid_new)):
  valid[i] = word_to_num[valid_new[i]]

# %%
num_batches = 30
num_tokens_in_batch = 200

# use a GPU for computation
device = torch.device("cuda")

# divide data into `num_batches` batches
def batchify(data, bsz):
    nbatch = data.size(0) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous() # reshape
    return data.to(device)

def get_batch(source, i, seq_len):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = source[i:i+seq_len]

    # targets are the same sequce of words but index shifed to the right, i.e. the next word
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

def repackage_hidden(h):
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

train = batchify(train, num_batches)
valid = batchify(valid, num_batches)

# %%
import torch.nn as nn

class EncoderDecoder(nn.Module):
  def __init__(self):
    super(EncoderDecoder, self).__init__()
    self.embed_size = 300
    self.hidden_size = 600

    # create embedding matrix, i.e. map each word to vector of ints
    self.embedding = nn.Embedding(len(vocab), self.embed_size)

    # initialize embedding matrix with a random uniform distribution
    initrange = 0.1
    self.embedding.weight.data.uniform_(-initrange, initrange)


    # RNN (LSTM) with dropout
    self.rnn = nn.LSTM(input_size=self.embed_size,
                       hidden_size=self.hidden_size)
    self.shrink = nn.Linear(self.hidden_size,
                            self.embed_size)
    self.drop = nn.Dropout(p=0.5)

    # decode layer predicts next words from our model
    self.decode = nn.Linear(self.embed_size, self.embedding.weight.size(0))
    self.decode.weight = self.embedding.weight
    self.decode.bias.data.zero_()


  def forward(self, input, hidden=None):
    x = self.embedding(input)
    if hidden is not None:
      x, hidden = self.rnn(x, hidden)
    else:
      x, hidden = self.rnn(x)
    x = F.relu(self.shrink(self.drop(x)))
    x = self.decode(x)
    return hidden, x

# %%
import torch.nn.functional as F
def training(model, data, targets, lr, hidden):
  # reset gradient
  model.zero_grad()

  # get prediction
  hidden, prediction_vector = model(data, hidden)
  prediction_vector = prediction_vector.view(targets.size(0), -1)

  # calculate loss
  loss = F.cross_entropy(input = prediction_vector, target = targets)

  # get gradients and perform back-propagation
  loss.backward()
  torch.nn.utils.clip_grad_norm_(model.parameters(), 0.25)
  for p in model.parameters():
      if p.grad is not None:
        p.data.add_(-lr, p.grad.data)

  return loss.item(), repackage_hidden(hidden)

# %%
def validation(model):
 # checks the predictions without updating parameters
  model.eval()
  hidden = None
  valid_loss = 0
  for i in range(0, valid.size(0) - num_tokens_in_batch, num_tokens_in_batch):
    data, targets = get_batch(valid, i, num_tokens_in_batch)
    hidden, prd = model(data, hidden)
    hidden = repackage_hidden(hidden)

    # softmax calculation
    softmax = torch.exp(prd) / torch.exp(prd).sum(dim=1, keepdim=True)

    # cross-entropy loss calculation
    log_softmax = torch.log(softmax)
    loss = -log_softmax[torch.arange(log_softmax.size(0)), targets].sum()
    validation_loss += loss.item()
  return valid_loss / (valid.size(0)/num_tokens_in_batch)

# %%
import numpy as np
import time

model = EncoderDecoder().float().to(device)
prev_valid_loss = 1e100

learning_rate = 20
num_batches = 20

# %%
import time

num_epochs = 150
timing = time.time()

# train specified number of epochs
for epoch in range(num_epochs):

  model.train()
  hidden = None
  train_loss = 0
  start_time = time.time()
  for i in range(0, train.size(0) - 1, num_tokens_in_batch):
    data, targets = get_batch(train, i, num_tokens_in_batch)

    # run the model and perform backpropagation
    loss, hidden = training(model, data, targets, learning_rate, hidden)
    train_loss += loss

  # evaluate how well the model predicts unseen validation data
  valid_loss = validation(model)

# updte learning rate if model is getting worse
  if valid_loss > prev_valid_loss:
    learning_rate /= 4.0

  train_loss /= (train.size(0)/num_tokens_in_batch)
  finish_time = time.time()
  print("Epoch {:2} took {:3.2f}s with train accuracy: {:7.2f}"\
        " and validation: {:7.2f}".format(epoch, finish_time - start_time,
                                          np.exp(train_loss),
                                          np.exp(valid_loss)))

  prev_valid_loss = valid_loss

total_time = (time.time() - timing)/60
print("Completed {} epochs in {:5.3f} minutes".format(num_epochs, total_time))
# Out:
# <ipython-input-16-bbf4e0e731c6>:18: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   p.data.add_(-lr, p.grad.data)
# Epoch  0 took 1.30s with train accuracy: 59015.78 and validation:    1.00
# Epoch  1 took 0.20s with train accuracy: 15321.27 and validation:    1.00
# Epoch  2 took 0.18s with train accuracy: 67450.02 and validation:    1.00
# Epoch  3 took 0.18s with train accuracy: 3178.93 and validation:    1.00
# Epoch  4 took 0.18s with train accuracy: 2267.42 and validation:    1.00
# Epoch  5 took 0.18s with train accuracy: 2448.98 and validation:    1.00
# Epoch  6 took 0.18s with train accuracy: 12555.55 and validation:    1.00
# Epoch  7 took 0.18s with train accuracy: 1339.53 and validation:    1.00
# Epoch  8 took 0.18s with train accuracy: 1774.00 and validation:    1.00
# Epoch  9 took 0.18s with train accuracy: 21498.12 and validation:    1.00
# Epoch 10 took 0.18s with train accuracy: 72975.81 and validation:    1.00
# Epoch 11 took 0.18s with train accuracy: 2147.09 and validation:    1.00
# Epoch 12 took 0.18s with train accuracy: 2205.89 and validation:    1.00
# Epoch 13 took 0.18s with train accuracy: 1188.81 and validation:    1.00
# Epoch 14 took 0.18s with train accuracy: 2058.40 and validation:    1.00
# Epoch 15 took 0.18s with train accuracy:  787.38 and validation:    1.00
# Epoch 16 took 0.18s with train accuracy:  885.13 and validation:    1.00
# Epoch 17 took 0.18s with train accuracy:  880.59 and validation:    1.00
# Epoch 18 took 0.18s with train accuracy:  673.66 and validation:    1.00
# Epoch 19 took 0.18s with train accuracy:  703.73 and validation:    1.00
# Epoch 20 took 0.18s with train accuracy:  572.55 and validation:    1.00
# Epoch 21 took 0.18s with train accuracy:  891.59 and validation:    1.00
# Epoch 22 took 0.18s with train accuracy:  601.28 and validation:    1.00
# Epoch 23 took 0.18s with train accuracy:  741.46 and validation:    1.00
# Epoch 24 took 0.18s with train accuracy:  565.80 and validation:    1.00
# Epoch 25 took 0.18s with train accuracy:  515.83 and validation:    1.00
# Epoch 26 took 0.18s with train accuracy:  513.95 and validation:    1.00
# Epoch 27 took 0.18s with train accuracy:  476.10 and validation:    1.00
# Epoch 28 took 0.18s with train accuracy:  460.92 and validation:    1.00
# Epoch 29 took 0.18s with train accuracy:  463.87 and validation:    1.00
# Epoch 30 took 0.18s with train accuracy:  402.47 and validation:    1.00
# Epoch 31 took 0.18s with train accuracy:  402.22 and validation:    1.00
# Epoch 32 took 0.18s with train accuracy:  434.68 and validation:    1.00
# Epoch 33 took 0.18s with train accuracy:  392.94 and validation:    1.00
# Epoch 34 took 0.18s with train accuracy:  384.28 and validation:    1.00
# Epoch 35 took 0.18s with train accuracy:  354.58 and validation:    1.00
# Epoch 36 took 0.18s with train accuracy:  374.50 and validation:    1.00
# Epoch 37 took 0.18s with train accuracy:  329.95 and validation:    1.00
# Epoch 38 took 0.18s with train accuracy:  332.42 and validation:    1.00
# Epoch 39 took 0.18s with train accuracy:  322.78 and validation:    1.00
# Epoch 40 took 0.18s with train accuracy:  334.62 and validation:    1.00
# Epoch 41 took 0.18s with train accuracy:  318.98 and validation:    1.00
# Epoch 42 took 0.18s with train accuracy:  316.94 and validation:    1.00
# Epoch 43 took 0.18s with train accuracy:  317.46 and validation:    1.00
# Epoch 44 took 0.18s with train accuracy:  251.31 and validation:    1.00
# Epoch 45 took 0.18s with train accuracy:  273.31 and validation:    1.00
# Epoch 46 took 0.18s with train accuracy:  259.92 and validation:    1.00
# Epoch 47 took 0.18s with train accuracy:  269.33 and validation:    1.00
# Epoch 48 took 0.18s with train accuracy:  264.32 and validation:    1.00
# Epoch 49 took 0.18s with train accuracy:  230.14 and validation:    1.00
# Epoch 50 took 0.18s with train accuracy:  232.35 and validation:    1.00
# Epoch 51 took 0.18s with train accuracy:  248.87 and validation:    1.00
# Epoch 52 took 0.18s with train accuracy:  245.35 and validation:    1.00
# Epoch 53 took 0.18s with train accuracy:  206.10 and validation:    1.00
# Epoch 54 took 0.18s with train accuracy:  224.82 and validation:    1.00
# Epoch 55 took 0.18s with train accuracy:  219.43 and validation:    1.00
# Epoch 56 took 0.18s with train accuracy:  200.06 and validation:    1.00
# Epoch 57 took 0.18s with train accuracy:  199.86 and validation:    1.00
# Epoch 58 took 0.18s with train accuracy:  221.94 and validation:    1.00
# Epoch 59 took 0.18s with train accuracy:  197.30 and validation:    1.00
# Epoch 60 took 0.18s with train accuracy:  197.79 and validation:    1.00
# Epoch 61 took 0.18s with train accuracy:  195.87 and validation:    1.00
# Epoch 62 took 0.18s with train accuracy:  189.61 and validation:    1.00
# Epoch 63 took 0.18s with train accuracy:  190.26 and validation:    1.00
# Epoch 64 took 0.18s with train accuracy:  171.16 and validation:    1.00
# Epoch 65 took 0.18s with train accuracy:  180.72 and validation:    1.00
# Epoch 66 took 0.18s with train accuracy:  166.10 and validation:    1.00
# Epoch 67 took 0.18s with train accuracy:  157.65 and validation:    1.00
# Epoch 68 took 0.18s with train accuracy:  165.14 and validation:    1.00
# Epoch 69 took 0.18s with train accuracy:  165.53 and validation:    1.00
# Epoch 70 took 0.18s with train accuracy:  157.89 and validation:    1.00
# Epoch 71 took 0.18s with train accuracy:  143.52 and validation:    1.00
# Epoch 72 took 0.18s with train accuracy:  147.55 and validation:    1.00
# Epoch 73 took 0.19s with train accuracy:  136.50 and validation:    1.00
# Epoch 74 took 0.18s with train accuracy:  144.44 and validation:    1.00
# Epoch 75 took 0.18s with train accuracy:  138.92 and validation:    1.00
# Epoch 76 took 0.18s with train accuracy:  134.65 and validation:    1.00
# Epoch 77 took 0.18s with train accuracy:  145.18 and validation:    1.00
# Epoch 78 took 0.19s with train accuracy:  140.40 and validation:    1.00
# Epoch 79 took 0.18s with train accuracy:  130.98 and validation:    1.00
# Epoch 80 took 0.18s with train accuracy:  122.57 and validation:    1.00
# Epoch 81 took 0.18s with train accuracy:  127.18 and validation:    1.00
# Epoch 82 took 0.18s with train accuracy:  118.72 and validation:    1.00
# Epoch 83 took 0.18s with train accuracy:  114.51 and validation:    1.00
# Epoch 84 took 0.19s with train accuracy:  113.58 and validation:    1.00
# Epoch 85 took 0.18s with train accuracy:  114.64 and validation:    1.00
# Epoch 86 took 0.18s with train accuracy:  108.97 and validation:    1.00
# Epoch 87 took 0.19s with train accuracy:  105.44 and validation:    1.00
# Epoch 88 took 0.18s with train accuracy:  107.69 and validation:    1.00
# Epoch 89 took 0.18s with train accuracy:  105.86 and validation:    1.00
# Epoch 90 took 0.18s with train accuracy:  101.46 and validation:    1.00
# Epoch 91 took 0.18s with train accuracy:   99.29 and validation:    1.00
# Epoch 92 took 0.18s with train accuracy:   96.55 and validation:    1.00
# Epoch 93 took 0.18s with train accuracy:   88.83 and validation:    1.00
# Epoch 94 took 0.19s with train accuracy:   92.74 and validation:    1.00
# Epoch 95 took 0.18s with train accuracy:   90.74 and validation:    1.00
# Epoch 96 took 0.19s with train accuracy:   86.08 and validation:    1.00
# Epoch 97 took 0.18s with train accuracy:   79.65 and validation:    1.00
# Epoch 98 took 0.18s with train accuracy:   79.34 and validation:    1.00
# Epoch 99 took 0.18s with train accuracy:   77.74 and validation:    1.00
# Epoch 100 took 0.18s with train accuracy:   75.22 and validation:    1.00
# Epoch 101 took 0.19s with train accuracy:   72.46 and validation:    1.00
# Epoch 102 took 0.19s with train accuracy:   70.75 and validation:    1.00
# Epoch 103 took 0.19s with train accuracy:   66.06 and validation:    1.00
# Epoch 104 took 0.19s with train accuracy:   70.37 and validation:    1.00
# Epoch 105 took 0.18s with train accuracy:   68.48 and validation:    1.00
# Epoch 106 took 0.18s with train accuracy:   65.94 and validation:    1.00
# Epoch 107 took 0.19s with train accuracy:   65.56 and validation:    1.00
# Epoch 108 took 0.19s with train accuracy:   61.45 and validation:    1.00
# Epoch 109 took 0.20s with train accuracy:   55.86 and validation:    1.00
# Epoch 110 took 0.20s with train accuracy:   57.47 and validation:    1.00
# Epoch 111 took 0.20s with train accuracy:   57.07 and validation:    1.00
# Epoch 112 took 0.20s with train accuracy:   53.01 and validation:    1.00
# Epoch 113 took 0.19s with train accuracy:   52.51 and validation:    1.00
# Epoch 114 took 0.18s with train accuracy:   49.14 and validation:    1.00
# Epoch 115 took 0.19s with train accuracy:   51.41 and validation:    1.00
# Epoch 116 took 0.19s with train accuracy:   46.88 and validation:    1.00
# Epoch 117 took 0.18s with train accuracy:   46.08 and validation:    1.00
# Epoch 118 took 0.19s with train accuracy:   43.26 and validation:    1.00
# Epoch 119 took 0.18s with train accuracy:   40.89 and validation:    1.00
# Epoch 120 took 0.19s with train accuracy:   39.40 and validation:    1.00
# Epoch 121 took 0.19s with train accuracy:   37.50 and validation:    1.00
# Epoch 122 took 0.18s with train accuracy:   37.21 and validation:    1.00
# Epoch 123 took 0.19s with train accuracy:   37.36 and validation:    1.00
# Epoch 124 took 0.19s with train accuracy:   34.66 and validation:    1.00
# Epoch 125 took 0.19s with train accuracy:   32.96 and validation:    1.00
# Epoch 126 took 0.19s with train accuracy:   32.38 and validation:    1.00
# Epoch 127 took 0.18s with train accuracy:   30.46 and validation:    1.00
# Epoch 128 took 0.19s with train accuracy:   28.61 and validation:    1.00
# Epoch 129 took 0.19s with train accuracy:   28.08 and validation:    1.00
# Epoch 130 took 0.19s with train accuracy:   27.29 and validation:    1.00
# Epoch 131 took 0.19s with train accuracy:   25.81 and validation:    1.00
# Epoch 132 took 0.19s with train accuracy:   24.24 and validation:    1.00
# Epoch 133 took 0.19s with train accuracy:   22.87 and validation:    1.00
# Epoch 134 took 0.19s with train accuracy:   23.84 and validation:    1.00
# Epoch 135 took 0.18s with train accuracy:   23.41 and validation:    1.00
# Epoch 136 took 0.19s with train accuracy:   22.19 and validation:    1.00
# Epoch 137 took 0.19s with train accuracy:   20.47 and validation:    1.00
# Epoch 138 took 0.19s with train accuracy:   18.76 and validation:    1.00
# Epoch 139 took 0.18s with train accuracy:   18.72 and validation:    1.00
# Epoch 140 took 0.19s with train accuracy:   17.33 and validation:    1.00
# Epoch 141 took 0.19s with train accuracy:   16.66 and validation:    1.00
# Epoch 142 took 0.19s with train accuracy:   15.68 and validation:    1.00
# Epoch 143 took 0.19s with train accuracy:   16.48 and validation:    1.00
# Epoch 144 took 0.19s with train accuracy:   15.12 and validation:    1.00
# Epoch 145 took 0.19s with train accuracy:   14.44 and validation:    1.00
# Epoch 146 took 0.18s with train accuracy:   13.30 and validation:    1.00
# Epoch 147 took 0.19s with train accuracy:   12.99 and validation:    1.00
# Epoch 148 took 0.19s with train accuracy:   12.40 and validation:    1.00
# Epoch 149 took 0.19s with train accuracy:   11.83 and validation:    1.00
# Completed 150 epochs in 0.480 minutes

# %%
from textwrap import wrap

# words to start the sentence with
prefixes = ['<n> love', '<n> shall', '<n> thou', '<n> the']

for prefix in prefixes:
  words_to_generate = 15

  # set the model to be in evaluation mode (i.e. no backprop!)
  model.eval()

  argmax_sent = None
  argmax_prob = 0
  collection = []
  for item in range(10):
    # make our starting words test data
    test = [word_to_num[word] for word in prefix.split()]
    probabilities = []

    # run the model on the same initial input and it's own generations until
    # we reach `word_to_generate`
    for w in range(words_to_generate):
      input = torch.from_numpy(np.array(test)).to(device)
      _, output = model(input.view(-1,1))

      # get the predicted next word
      last_pred = output[-1,:,:].squeeze()

      # sample words from the probability prediction, rather than using the highest probability each time
      if item > 0:
        last_pred /= 0.70

        # create distribution
        dist = torch.distributions.categorical.Categorical(logits=last_pred)

        predicted_idx = dist.sample().item()

      else:
        # take the most probable word
        _, predicted_idx = last_pred.max(0)
        predicted_idx = predicted_idx.item()

      # save this probability
      value = F.log_softmax(last_pred,-1)[predicted_idx].item()
      test.append(predicted_idx)
      probabilities.append(value)

    if item > 0:
      # save generated sentence and its score to a list
      generation = (np.exp(np.sum(probabilities)), \
                        " ".join([num_to_word[w] for w in test]))
      if generation not in collection:
        collection.append(generation)
    else:
      argmax_sent = " ".join([num_to_word[w] for w in test])
      argmax_prob = np.exp(np.sum(probabilities))

  # get the best model predictions
  collection.sort()
  collection.reverse()
  print("Choosing Best Probability Generation:")
  print("{:.2E}:  {}\n".format(argmax_prob,"\n\t\t".join(wrap(argmax_sent))))
  print("\nSampled Generations:")
  for probability, sent in collection[:10]:
    print("{:.2E}:  {}\n".format(probability, "\n\t\t".join(wrap(sent))))

  print("\n\n\n")
# Out:
# Choosing Best Probability Generation:
# 2.14E-08:  <n> love , and a Montague . </n> <n> What 's this ? what a man are
#
#
# Sampled Generations:
# 3.79E-09:  <n> love , of love ; Who if thou think'st ' t is not for a dream
#
# 2.89E-09:  <n> love , I will bear a brain : abut , if he do not ; or
#
# 1.20E-10:  <n> love , no limit 's doom ; or ' t is a foul th ing .
#
# 8.93E-11:  <n> love , how art thou fishifi ed to your chamb er : An if thou
# 		couldst
#
# 6.70E-12:  <n> love , that would fain dream him . How now is this did made a
# 		month
#
# 1.57E-12:  <n> love , away ! Pray back ; you know not so deep as well as they
#
# 6.84E-13:  <n> love , so love . </n> <n> Thou wilt not stay me </n> <n> No </n>
#
# 1.05E-13:  <n> love , you are beguil ed and sought a maid </n> <n> Yea , good
# 		night
#
# 3.91E-15:  <n> love , and heaven can not excuse the circumstance : all my
# 		marriage was here comes
#
#
#
#
#
# Choosing Best Probability Generation:
# 8.15E-09:  <n> shall she be here : when he hath forsworn ; but ' t is no less
#
#
# Sampled Generations:
# 4.11E-07:  <n> shall Thursday fall upon the cheek of night make her eyes . </n>
# 		<n> If love
#
# 4.10E-09:  <n> shall Thursday me by thy pains . </n> <n> O single  sol ed morn me
#
# 1.88E-09:  <n> shall Thursday me a loath ed death ; This day is dead ! For ' t
#
# 1.35E-11:  <n> shall you share all so day : and thou art worn in my ancient ears
# 		?
#
# 6.83E-13:  <n> shall ev er weep thy cheek should wash 'd out ; the winds  weary
# 		's
#
# 4.61E-13:  <n> shall if in me To bedeck me : He should she be thus ? What with
#
# 1.20E-13:  <n> shall not choose more worthy a wing ed marchpane ; But ' t is no
# 		wit
#
# 7.98E-14:  <n> shall you fall all a highway to his pleasure : Then so livery is a
# 		gentlemanlike
#
# 1.56E-15:  <n> shall hour hence ; For what thou must were a guest in joy ! why
# 		with
#
#
#
#
#
# Choosing Best Probability Generation:
# 1.82E-08:  <n> thou art not so much : but my ho ly ord er ; or a '
#
#
# Sampled Generations:
# 2.23E-09:  <n> thou art not no hands to tell me as thou canst not not a sin :
#
# 2.26E-10:  <n> thou art not backward all so soon is my wedd ing eye : It is not
#
# 1.68E-10:  <n> thou shalt not upon the cheek of a foe . </n> <n> How now ! why
#
# 6.20E-11:  <n> thou art not backward all this fatal will that slaught er 'd a
# 		word of joy
#
# 3.89E-11:  <n> thou art not so . </n> <n> So thrive is Romeo ! You are a saucy
#
# 6.56E-12:  <n> thou art not As love the ears ? give up in this neighbour 's bone
# 		.
#
# 2.01E-12:  <n> thou art not nor : but she is not down : My lord , Tybalt </n>
#
# 6.24E-14:  <n> thou art not like an old murder er the sin of a fiend In joy :
#
# 4.27E-14:  <n> thou canst not fish with patience ' kiss . </n> <n> Madam , fair
# 		saint ;
#
#
#
#
#
# Choosing Best Probability Generation:
# 9.28E-09:  <n> the prince will doom thee death ; This is a nobleman in little
# 		stars : A
#
#
# Sampled Generations:
# 4.84E-06:  <n> the prince cries man ! the punto reverso ! the hai ! the hai !
# 		</n>
#
# 7.87E-09:  <n> the sweetest honey Is fair and hard 's noses 'd the imagin ed
# 		happiness that lies
#
# 5.20E-10:  <n> the sweetest honey Is fair and hard 's beams brawl . </n> <n> O
# 		think'st thou
#
# 4.26E-10:  <n> the prince will doom thee death : Look thy heavy of cats ? </n>
# 		<n> We
#
# 5.99E-11:  <n> the prince stint be gone ! Too Rosaline hath brisk shame ; the
# 		fish er should
#
# 8.00E-12:  <n> the prince will doom thee death : Therefore thy brow out to thy
# 		shape in noon
#
# 3.15E-13:  <n> the prince shows doom ; here comes not so hard ? no men 's death !
#
# 2.73E-14:  <n> the prince will doom thee physic Will thou couldst upon the lazy
# 		's brow ; Had
#
# 1.77E-14:  <n> the day will you not ! O courteous Juliet ! down back ! Is she is

# %% [markdown]
# # Flask Deployment

# %%
def prediction(prefix):
  # words to start the sentence with
  prefixes = [prefix]

  # What do we want the model to start the sentence with?
  for prefix in prefixes:
    words_to_generate = 15

    # set the model to be in evaluation mode (i.e. no backprop!)
    model.eval()

    argmax_sent = None
    argmax_prob = 0
    collection = []
    for item in range(10):
      # make our starting words test data
      test = [word_to_num[word] for word in prefix.split()]
      probabilities = []

      # run the model on the same initial input and it's own generations until
      # we reach `word_to_generate`
      for w in range(words_to_generate):
        input = torch.from_numpy(np.array(test)).to(device)
        _, output = model(input.view(-1,1))

        # get the predicted next word
        last_pred = output[-1,:,:].squeeze()

        # sample words from the probability prediction, rather than using the highest probability each time
        if item > 0:
          last_pred /= 0.70

          # create distribution
          dist = torch.distributions.categorical.Categorical(logits=last_pred)

          predicted_idx = dist.sample().item()

        else:
          # take the most probable word
          _, predicted_idx = last_pred.max(0)
          predicted_idx = predicted_idx.item()

        # save this probability
        value = F.log_softmax(last_pred,-1)[predicted_idx].item()
        test.append(predicted_idx)
        probabilities.append(value)

      if item > 0:
        # save generated sentence and its score to a list
        generation = (np.exp(np.sum(probabilities)), \
                          " ".join([num_to_word[w] for w in test]))
        if generation not in collection:
          collection.append(generation)
      else:
        argmax_sent = " ".join([num_to_word[w] for w in test])
        argmax_prob = np.exp(np.sum(probabilities))

    # get the best model predictions
    collection.sort()
    collection.reverse()

    return collection

# %%
from flask import Flask
from flask_ngrok import run_with_ngrok
app = Flask(__name__)
run_with_ngrok(app)
@app.route("/")
def hom():
    return "Hello World"

@app.route("/<prefix>")
def home(prefix):
    predictions = prediction(prefix)
    html = ""
    for pred in predictions:
      html += "<h1>"+pred[-1]+"</h1>"
    return html

if __name__ == '__main__':
    app.run()
